# %% [markdown]
# # Módulo 1: Análise exploratória de dados

# %% [markdown]
# ## Importando dados de Atendimento
# #### Etapas realizadas:
#
# - Importada a biblioteca "PANDAS";
# - Realizada a leitura do arquido utilizando o "pd.read_csv";
# - Colar o caminho do arquivo (que deve ter sido previamente carregado);
# - Utilizar o "encoding" para dizer qual o formato do arquivo (Ex.: UTF-8, ISO-8859-1);
# - Utilizar o "skiprows" para indicar quantas linhas devem ser puladas para iniciar a leitura do código;
# - Utilizar "sep" para idicar qual o separador de dados está sendo utilizado (Ex.: vírgula, ponto e vírgula...);
# - Utilizar o "skipfooter" para indicar quantas linhas devem ser puladas no final;
# - Utilizar o "thousands" para idicar qual o separador de milhar está sendo utilizado no arquivo (se é vírgula ou ponto);
# - Utilizar o "decimal" para indicar o separador de casas decimai utilizado no arquivo (se ponto ou vírgula).

# %% [markdown]
# ## Importando dados de Atendimento
# #### Etapas realizadas:
#
# - Importada a biblioteca "PANDAS";
# - Realizada a leitura do arquido utilizando o "pd.read_csv";
# - Colar o caminho do arquivo (que deve ter sido previamente carregado);
# - Utilizar o "encoding" para dizer qual o formato do arquivo (Ex.: UTF-8, ISO-8859-1);
# - Utilizar o "skiprows" para indicar quantas linhas devem ser puladas para iniciar a leitura do código;
# - Utilizar "sep" para idicar qual o separador de dados está sendo utilizado (Ex.: vírgula, ponto e vírgula...);
# - Utilizar o "skipfooter" para indicar quantas linhas devem ser puladas no final;
# - Utilizar o "thousands" para idicar qual o separador de milhar está sendo utilizado no arquivo (se é vírgula ou ponto);
# - Utilizar o "decimal" para indicar o separador de casas decimai utilizado no arquivo (se ponto ou vírgula).

# %% [markdown]
# ## Importando dados de Atendimento
# #### Etapas realizadas:
#
# - Importada a biblioteca "PANDAS";
# - Realizada a leitura do arquido utilizando o "pd.read_csv";
# - Colar o caminho do arquivo (que deve ter sido previamente carregado);
# - Utilizar o "encoding" para dizer qual o formato do arquivo (Ex.: UTF-8, ISO-8859-1);
# - Utilizar o "skiprows" para indicar quantas linhas devem ser puladas para iniciar a leitura do código;
# - Utilizar "sep" para idicar qual o separador de dados está sendo utilizado (Ex.: vírgula, ponto e vírgula...);
# - Utilizar o "skipfooter" para indicar quantas linhas devem ser puladas no final;
# - Utilizar o "thousands" para idicar qual o separador de milhar está sendo utilizado no arquivo (se é vírgula ou ponto);
# - Utilizar o "decimal" para indicar o separador de casas decimai utilizado no arquivo (se ponto ou vírgula).

# %%
import pandas as pd

# %% [markdown]
# ## Analisando dados de produção hospitalar

# %%
#### Dados é um dataframe
dados = pd.read_csv('C:/Users/flora/OneDrive/Documentos/POS_GRADUCAO/Fase 01 - Data Analysis and Exploration/1 - Análise Exploratória de Dados/Aula 01/PROCEDIMENTOS_HOSPITALARES_DO_SUS-ANO_ATENDIMENTO.csv', encoding='ISO-8859-1', skiprows=3, sep=';', skipfooter=12, thousands='.', decimal=',', engine='python')

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...    2023/Mai    2023/Jun    2023/Jul  \
# 0        -        -        -  ... 12505974.83 12009682.89 11892438.13
# 1        -        -        -  ...  4861672.52  5282731.30  4830246.24
# 2        -        -        -  ... 22951007.22 22636889.89 22193955.78
# 3        -        -        -  ...  4915988.80  4097022.28  3814616.24
# 4        -        -        -  ... 52730367.64 49576192.93 49819035.62
#
#      2023/Ago    2023/Set    2023/Out    2023/Nov    2023/Dez     2024/Jan  \
# 0 12737928.88 12068445.93 10814659.45  7839878.93  4969181.30   2434117.87
# 1  4925043.24  4329288.81  4071963.23  3233614.21  1394717.40            -
# 2 21762872.97 16686364.04 17051515.93 14725982.12 11345788.28   4838198.31
# 3  3180791.10  2362582.36  1585002.57   165184.76    91360.44     41945.05
# 4 52500501.45 51714821.84 51237171.71 49646581.93 32989201.74  13610385.98
#
#           Total
# 0 1394262146.50
# 1  587778407.94
# 2 2613559191.21
# 3  451170144.15
# 4 6322687933.44
#
# [5 rows x 321 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...      2023/Mai      2023/Jun  \
# 22        -        -        -        -  ...  1.199118e+08  1.141806e+08
# 23        -        -        -        -  ...  2.701212e+07  2.598033e+07
# 24        -        -        -        -  ...  2.447079e+07  2.292929e+07
# 25        -        -        -        -  ...  5.013406e+07  4.793557e+07
# 26        -        -        -        -  ...  2.991984e+07  2.833759e+07
#
#         2023/Jul      2023/Ago      2023/Set      2023/Out      2023/Nov  \
# 22  1.148215e+08  1.208417e+08  1.140196e+08  1.161876e+08  1.017237e+08
# 23  2.740884e+07  2.776104e+07  2.589779e+07  2.435644e+07  1.797520e+07
# 24  2.355093e+07  2.424369e+07  2.242473e+07  2.157215e+07  1.875799e+07
# 25  4.941291e+07  4.976387e+07  4.804023e+07  4.798996e+07  4.518010e+07
# 26  2.954441e+07  3.086417e+07  2.963623e+07  2.977684e+07  2.778567e+07
#
#        2023/Dez     2024/Jan         Total
# 22  79016335.07  35097902.08  1.675015e+10
# 23  11104710.76   3622254.04  3.219624e+09
# 24  13608235.28   7711923.78  2.988457e+09
# 25  35603860.42  18035437.49  6.682626e+09
# 26  22830282.42  15359150.30  3.543027e+09
#
# [5 rows x 321 columns]

# %%
dados.mean(numeric_only=True)
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2023/Set    6.395927e+07
# 2023/Out    6.465797e+07
# 2023/Nov    5.700142e+07
# 2023/Dez    4.504372e+07
# Total       8.578335e+09
# Length: 198, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 321 entries, Unidade da Federação to Total
# dtypes: float64(198), object(123)
# memory usage: 67.8+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean(numeric_only=True)
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2023/Set     63959268.28
# 2023/Out     64657967.71
# 2023/Nov     57001423.07
# 2023/Dez     45043722.01
# Total      8578335035.65
# Length: 198, dtype: float64

# %% [markdown]
# ## Importando dados de Processamento
#
# ### Etapas realizadas:
# - Importada a biblioteca "PANDAS";
# - Realizada a leitura do arquido utilizando o "pd.read_csv";
# - Colar o caminho do arquivo (que deve ter sido previamente carregado);
# - Utilizar o "encoding" para dizer qual o formato do arquivo (Ex.: UTF-8, ISO-8859-1);
# - Utilizar o "skiprows" para indicar quantas linhas devem ser puladas para iniciar a leitura do código;
# - Utilizar "sep" para idicar qual o separador de dados está sendo utilizado (Ex.: vírgula, ponto e vírgula...);
# - Utilizar o "skipfooter" para indicar quantas linhas devem ser puladas no final;
# - Utilizar o "thousands" para idicar qual o separador de milhar está sendo utilizado no arquivo (se é vírgula ou ponto);
# - Utilizar o "decimal" para indicar o separador de casas decimai utilizado no arquivo (se ponto ou vírgula). vírgula).

# %%
dados_proc = pd.read_csv ('C:/Users/flora/OneDrive/Documentos/POS_GRADUCAO/Fase 01 - Data Analysis and Exploration/1 - Análise Exploratória de Dados/Aula 01/PROCEDIMENTOS_HOSPITALARES_DO_SUS-PROCESSAMENTO.csv', encoding='ISO-8859-1', skiprows=3, sep=';', skipfooter=12, thousands='.', decimal=',', engine='python')

# %%
dados_proc.head()
# Out:
#   Unidade da Federação    2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# 0          11 Rondônia  1388528.39  2931283.42  1541682.52  1525314.96
# 1              12 Acre   902416.00  1497206.26  1794028.48  1730469.42
# 2          13 Amazonas  4735529.42  7118990.57  8196635.49  8259378.42
# 3           14 Roraima   657889.53   777939.31   718688.03   839994.39
# 4              15 Pará 18864744.11 19553758.20 21937342.70 20842829.69
#
#      2008/Mai    2008/Jun    2008/Jul    2008/Ago    2008/Set  ...  \
# 0  1645953.84  1406150.68  3065279.01  3231494.61  3117178.63  ...
# 1  1819443.92  1828496.00  2511754.59  2089107.14  2275708.53  ...
# 2  7831399.90  8477273.62  9368858.72  9352532.70  9363099.35  ...
# 3   862347.96   832440.66   996693.09   894271.18   910424.17  ...
# 4 23249952.88 23240687.56 24002223.56 23341218.03 25172261.32  ...
#
#      2023/Mai    2023/Jun    2023/Jul    2023/Ago    2023/Set    2023/Out  \
# 0 13767058.64 11273846.83 12443977.87 13054654.77 11274549.92 12082214.04
# 1  4845006.75  5124899.00  5692793.93  4561281.78  4019181.11  4150926.64
# 2 21710028.09 22198453.04 24809424.63 25005960.66 17522338.72 19613290.58
# 3  4435042.77  3817361.58  4040988.99  4766375.31  1679849.33  2443674.72
# 4 46925899.02 45938305.83 54094884.03 50116544.12 51268388.79 50646320.52
#
#      2023/Nov    2023/Dez     2024/Jan         Total
# 0 11392759.99  9603361.10  10516070.26 1394262146.50
# 1  5712687.05  3503827.09            -  587778407.94
# 2 18387673.59 14265257.60  15065867.12 2613559191.21
# 3  2868626.39  2077360.03   2164371.02  451170144.15
# 4 55501176.43 54223823.56  43689467.84 6322687933.44
#
# [5 rows x 195 columns]

# %%
dados_proc.tail()
# Out:
#      Unidade da Federação    2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# 22   43 Rio Grande do Sul 30931325.46 57363420.01 51547794.07 56673338.49
# 23  50 Mato Grosso do Sul  5377392.11  7002472.61  8423933.19  8797487.68
# 24         51 Mato Grosso  4795299.01  8684882.23  7886243.14  8794109.79
# 25               52 Goiás 15310637.29 22258668.68 21442515.75 20921212.45
# 26    53 Distrito Federal  4745919.19  7632480.67  9647203.26 11098732.99
#
#       2008/Mai    2008/Jun    2008/Jul    2008/Ago    2008/Set  ...  \
# 22 48397733.07 52413429.62 56636376.98 56113054.70 55356224.30  ...
# 23  9770421.80 10905392.18 10249299.82  9671553.45 10218511.05  ...
# 24  9231645.40 10221763.77  9163314.28  9243148.81  9052354.89  ...
# 25 21615970.67 18270043.87 20540517.13 20650730.67 20868443.56  ...
# 26 12891719.72 12850125.67 12565646.74 13710857.89 13165106.20  ...
#
#        2023/Mai     2023/Jun     2023/Jul     2023/Ago     2023/Set  \
# 22 112385822.04 113809028.30 116985178.63 120027121.08 116546657.80
# 23  26973943.11  26354221.47  26569066.08  27768462.56  28200723.03
# 24  23431985.13  24728541.29  24130933.81  22608901.38  23329871.28
# 25  50235627.95  44674462.22  53622374.91  51008354.28  49885683.22
# 26  27495227.73  28258576.00  29034177.33  30961244.28  31610313.47
#
#        2023/Out     2023/Nov     2023/Dez      2024/Jan          Total
# 22 122325557.64 114892531.95 114464874.02  120732038.67 16750147966.65
# 23  26783833.64  27456434.20  26922668.28   23959476.62  3219624366.70
# 24  22552033.63  22790096.76  19782985.94   21462469.97  2988456549.66
# 25  50434366.44  47764974.85  50332961.30   47555420.60  6682627768.18
# 26  29140330.80  30810835.09  29465293.81   31878001.55  3543027009.96
#
# [5 rows x 195 columns]

# %%
dados_proc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 195 entries, Unidade da Federação to Total
# dtypes: float64(192), object(3)
# memory usage: 41.3+ KB

# %%
dados_proc.mean(numeric_only = True)
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2023/Set     65189094.24
# 2023/Out     66941705.27
# 2023/Nov     65725826.24
# 2023/Dez     65537138.18
# Total      8578342381.93
# Length: 192, dtype: float64

# %%
dados.plot(x="Unidade da Federação", y = "2008/Ago")
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
dados.plot(x="Unidade da Federação", y = "2008/Ago", kind="bar")
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

axis = dados.plot(x="Unidade da Federação", y = "2008/Ago", kind="bar", figsize=(9,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title ("Valor por unidade da Federação")
plt.xticks(rotation=75)
plt.show ()

# %% [markdown]
# ## Aula 3.1

# %%
dados [["2008/Ago","2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...    2023/Mai    2023/Jun    2023/Jul  \
# 0        -        -        -  ... 12505974.83 12009682.89 11892438.13
# 1        -        -        -  ...  4861672.52  5282731.30  4830246.24
# 2        -        -        -  ... 22951007.22 22636889.89 22193955.78
# 3        -        -        -  ...  4915988.80  4097022.28  3814616.24
# 4        -        -        -  ... 52730367.64 49576192.93 49819035.62
#
#      2023/Ago    2023/Set    2023/Out    2023/Nov    2023/Dez     2024/Jan  \
# 0 12737928.88 12068445.93 10814659.45  7839878.93  4969181.30   2434117.87
# 1  4925043.24  4329288.81  4071963.23  3233614.21  1394717.40            -
# 2 21762872.97 16686364.04 17051515.93 14725982.12 11345788.28   4838198.31
# 3  3180791.10  2362582.36  1585002.57   165184.76    91360.44     41945.05
# 4 52500501.45 51714821.84 51237171.71 49646581.93 32989201.74  13610385.98
#
#           Total
# 0 1394262146.50
# 1  587778407.94
# 2 2613559191.21
# 3  451170144.15
# 4 6322687933.44
#
# [5 rows x 321 columns]

# %%
dados.columns
# Out:
# Index(['Unidade da Federação', '1992/Mar', '1992/Abr', '1993/Mai', '1993/Dez',
#        '1994/Jan', '1994/Fev', '1994/Mai', '1994/Ago', '1994/Nov',
#        ...
#        '2023/Mai', '2023/Jun', '2023/Jul', '2023/Ago', '2023/Set', '2023/Out',
#        '2023/Nov', '2023/Dez', '2024/Jan', 'Total'],
#       dtype='object', length=321)

# %%
dados.mean(numeric_only=True).index.tolist()
# Out:
# ['2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  '2020/Ago',
#  '2020/Set',
#  '2020/Out',
#  '2020/Nov',
#  '2020/Dez',
#  '2021/Jan',
#  '2021/Fev',
#  '2021/Mar',
#  '2021/Abr',
#  '2021/Mai',
#  '2021/Jun',
#  '2021/Jul',
#  '2021/Ago',
#  '2021/Set',
#  '2021/Out',
#  '2021/Nov',
#  '2021/Dez',
#  '2022/Jan',
#  '2022/Fev',
#  '2022/Mar',
#  '2022/Abr',
#  '2022/Mai',
#  '2022/Jun',
#  '2022/Jul',
#  '2022/Ago',
#  '2022/Set',
#  '2022/Out',
#  '2022/Nov',
#  '2022/Dez',
#  '2023/Jan',
#  '2023/Fev',
#  '2023/Mar',
#  '2023/Abr',
#  '2023/Mai',
#  '2023/Jun',
#  '2023/Jul',
#  '2023/Ago',
#  '2023/Set',
#  '2023/Out',
#  '2023/Nov',
#  '2023/Dez',
#  'Total']

# %%
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.columns
# Out:
# Index(['Unidade da Federação', '1992/Mar', '1992/Abr', '1993/Mai', '1993/Dez',
#        '1994/Jan', '1994/Fev', '1994/Mai', '1994/Ago', '1994/Nov',
#        ...
#        '2023/Mai', '2023/Jun', '2023/Jul', '2023/Ago', '2023/Set', '2023/Out',
#        '2023/Nov', '2023/Dez', '2024/Jan', 'Total'],
#       dtype='object', length=321)

# %%
colunas_usaveis = dados.mean(numeric_only=True).index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis[:5]
# Out:
# ['Unidade da Federação', '2007/Ago', '2007/Set', '2007/Out', '2007/Nov']

# %%
dados_usaveis = dados[colunas_usaveis]
dados_usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2023/Abr  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ... 12460222.12
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  4400113.11
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 21147835.83
# 3   808448.39   771687.83   876091.18   896952.53  ...  4659152.88
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 48219884.00
#
#      2023/Mai    2023/Jun    2023/Jul    2023/Ago    2023/Set    2023/Out  \
# 0 12505974.83 12009682.89 11892438.13 12737928.88 12068445.93 10814659.45
# 1  4861672.52  5282731.30  4830246.24  4925043.24  4329288.81  4071963.23
# 2 22951007.22 22636889.89 22193955.78 21762872.97 16686364.04 17051515.93
# 3  4915988.80  4097022.28  3814616.24  3180791.10  2362582.36  1585002.57
# 4 52730367.64 49576192.93 49819035.62 52500501.45 51714821.84 51237171.71
#
#      2023/Nov    2023/Dez         Total
# 0  7839878.93  4969181.30 1394262146.50
# 1  3233614.21  1394717.40  587778407.94
# 2 14725982.12 11345788.28 2613559191.21
# 3   165184.76    91360.44  451170144.15
# 4 49646581.93 32989201.74 6322687933.44
#
# [5 rows x 199 columns]

# %%
dados_usaveis = dados_usaveis.set_index("Unidade da Federação")
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
#                         2008/Mai  ...    2023/Abr    2023/Mai    2023/Jun  \
# Unidade da Federação              ...
# 11 Rondônia           2280382.58  ... 12460222.12 12505974.83 12009682.89
# 12 Acre               2226577.93  ...  4400113.11  4861672.52  5282731.30
# 13 Amazonas           9079902.15  ... 21147835.83 22951007.22 22636889.89
# 14 Roraima            1027288.73  ...  4659152.88  4915988.80  4097022.28
# 15 Pará              23861080.80  ... 48219884.00 52730367.64 49576192.93
#
#                         2023/Jul    2023/Ago    2023/Set    2023/Out  \
# Unidade da Federação
# 11 Rondônia          11892438.13 12737928.88 12068445.93 10814659.45
# 12 Acre               4830246.24  4925043.24  4329288.81  4071963.23
# 13 Amazonas          22193955.78 21762872.97 16686364.04 17051515.93
# 14 Roraima            3814616.24  3180791.10  2362582.36  1585002.57
# 15 Pará              49819035.62 52500501.45 51714821.84 51237171.71
#
#                         2023/Nov    2023/Dez         Total
# Unidade da Federação
# 11 Rondônia           7839878.93  4969181.30 1394262146.50
# 12 Acre               3233614.21  1394717.40  587778407.94
# 13 Amazonas          14725982.12 11345788.28 2613559191.21
# 14 Roraima             165184.76    91360.44  451170144.15
# 15 Pará              49646581.93 32989201.74 6322687933.44
#
# [5 rows x 198 columns]

# %%
dados_usaveis["2008/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    2938286.29
# 12 Acre        1886871.84
# 13 Amazonas    8331763.97
# 14 Roraima     1045291.11
# 15 Pará       23259148.28
# Name: 2008/Ago, dtype: float64

# %%
dados_usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2023/Set     4329288.81
# 2023/Out     4071963.23
# 2023/Nov     3233614.21
# 2023/Dez     1394717.40
# Total      587778407.94
# Name: 12 Acre, Length: 198, dtype: float64

# %%
dados_usaveis.iloc[1]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2023/Set     4329288.81
# 2023/Out     4071963.23
# 2023/Nov     3233614.21
# 2023/Dez     1394717.40
# Total      587778407.94
# Name: 12 Acre, Length: 198, dtype: float64

# %%
dados_usaveis.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
dados_usaveis.T.plot(figsize=(12,6))
##o T é para transpor o gráfico entre x e y
# Out:
# <Axes: >

# %%
dados_usaveis.T.tail()
# Out:
# Unidade da Federação   11 Rondônia      12 Acre   13 Amazonas   14 Roraima  \
# 2023/Set               12068445.93   4329288.81   16686364.04   2362582.36
# 2023/Out               10814659.45   4071963.23   17051515.93   1585002.57
# 2023/Nov                7839878.93   3233614.21   14725982.12    165184.76
# 2023/Dez                4969181.30   1394717.40   11345788.28     91360.44
# Total                1394262146.50 587778407.94 2613559191.21 451170144.15
#
# Unidade da Federação       15 Pará     16 Amapá  17 Tocantins   21 Maranhão  \
# 2023/Set               51714821.84   3331263.48    9629774.49   40399651.12
# 2023/Out               51237171.71   3543500.85    6722881.55   39865036.47
# 2023/Nov               49646581.93   3052663.75    5032974.30   33146563.03
# 2023/Dez               32989201.74   2768546.16    2582404.81   23303880.58
# Total                6322687933.44 434057663.03 1364198743.40 5245996055.35
#
# Unidade da Federação      22 Piauí      23 Ceará  ...  32 Espírito Santo  \
# 2023/Set               23745716.86   63072515.00  ...        40478673.23
# 2023/Out               22878158.31   64716508.58  ...        41809848.79
# 2023/Nov               19415247.34   54152759.50  ...        35767904.73
# 2023/Dez               15246017.28   39043483.57  ...        27677906.02
# Total                3055504906.18 8854791965.38  ...      4784325123.75
#
# Unidade da Federação  33 Rio de Janeiro   35 São Paulo      41 Paraná  \
# 2023/Set                   122532382.59   362854888.92   152226546.07
# 2023/Out                   127245165.17   374629976.37   151522479.20
# 2023/Nov                   110293990.40   335486802.01   136377606.71
# 2023/Dez                    85884256.01   289203731.18   108392132.04
# Total                    14318869113.09 54440115497.18 19763419297.81
#
# Unidade da Federação  42 Santa Catarina  43 Rio Grande do Sul  \
# 2023/Set                    88811503.07          114019622.04
# 2023/Out                    89924700.23          116187553.64
# 2023/Nov                    80434789.80          101723680.10
# 2023/Dez                    59848379.26           79016335.07
# Total                    10780033131.67        16750147966.65
#
# Unidade da Federação  50 Mato Grosso do Sul  51 Mato Grosso      52 Goiás  \
# 2023/Set                        25897790.89     22424730.11   48040227.82
# 2023/Out                        24356440.44     21572148.20   47989959.81
# 2023/Nov                        17975196.66     18757993.99   45180102.56
# 2023/Dez                        11104710.76     13608235.28   35603860.42
# Total                         3219624366.70   2988456549.66 6682626416.14
#
# Unidade da Federação  53 Distrito Federal
# 2023/Set                      29636228.70
# 2023/Out                      29776844.99
# 2023/Nov                      27785666.95
# 2023/Dez                      22830282.42
# Total                       3543027009.96
#
# [5 rows x 27 columns]

# %% [markdown]
# #### O erro que aparece abaixo, ocorre à partir da segunda execução, pois a linha "Total" já foi removida e atualizada nos plots acimas.

# 51 Mato Grosso             38977665.54
# 52 Goiás                   80007952.86
# 53 Distrito Federal        36449969.33
# dtype: float64

# %% [markdown]
# ### Desafio: reposicionar a legenda e retocar o gráfico, e incluir títulos nos dois eixos.

# %%
import matplotlib.pyplot as plt 

dados = dados_usaveis.T.plot(figsize=(12,6))
dados.legend(bbox_to_anchor=(1.05, 1), loc='upper left', prop={'size': 8.15})

plt.title ("Valor por período")
# Out:
# Text(0.5, 1.0, 'Valor por período')

# %% [markdown]
# ## Aula 3.2

# %%
dados_usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis[:7].T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
dados_usaveis.sample(n=7)
# Out:
#                       2007/Ago   2007/Set    2007/Out    2007/Nov    2007/Dez  \
# Unidade da Federação
# 41 Paraná            554800.22 1431708.01  4630402.44 11120030.79 28790722.87
# 32 Espírito Santo     57408.11  284224.80  1152115.25  2296383.23  5724199.54
# 21 Maranhão          385330.18 1018352.93  2277717.78  4334468.23  8832514.85
# 31 Minas Gerais      971394.37 2861781.50 10018011.35 21730281.63 43429517.54
# 51 Mato Grosso        63562.50  232444.62   927219.59  1740439.60  5394225.43
# 53 Distrito Federal  191951.47  769966.25  2165619.56  3813256.48  7121965.42
# 28 Sergipe            27453.63   78565.19   122952.94   775705.52  2765495.63
#
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 41 Paraná             58081334.45 48855046.46 55611791.07 56115135.82
# 32 Espírito Santo     16212109.41 10032886.43 12262049.08 12453466.98
# 21 Maranhão           21551600.33 13452263.93 14750895.33 15148647.11
# 31 Minas Gerais      206936986.60 70301089.50 79119005.51 79046322.41
# 51 Mato Grosso         8213438.64  7929894.93  9416367.68  9390588.03
# 53 Distrito Federal   10561085.46 10215956.80 11627918.26 11922015.36
# 28 Sergipe             5439985.99  4636850.76  5017838.07  5265951.03
#
#                         2008/Mai  ...     2023/Mar     2023/Abr     2023/Mai  \
# Unidade da Federação              ...
# 41 Paraná            55574831.93  ... 154908096.89 140829790.10 155962309.38
# 32 Espírito Santo    11789786.09  ...  41981809.80  38767723.99  43179230.48
# 21 Maranhão          14543679.92  ...  40977333.48  37720583.93  42107180.54
# 31 Minas Gerais      79268070.12  ... 216708207.72 199365192.93 222826001.02
# 51 Mato Grosso        9378197.25  ...  23311478.85  21859985.36  24470787.76
# 53 Distrito Federal  11900817.00  ...  28980515.22  28463928.34  29919839.16
# 28 Sergipe            5367094.94  ...  15105725.57  14514256.62  15423708.12
#
#                          2023/Jun     2023/Jul     2023/Ago     2023/Set  \
# Unidade da Federação
# 41 Paraná            150601146.87 148652511.49 158580037.53 152226546.07
# 32 Espírito Santo     40733853.91  41223811.54  42930850.56  40478673.23
# 21 Maranhão           41608384.22  41589508.81  41901513.18  40399651.12
# 31 Minas Gerais      209415536.12 215203958.92 223107676.13 214385538.67
# 51 Mato Grosso        22929285.47  23550934.50  24243689.65  22424730.11
# 53 Distrito Federal   28337591.67  29544407.37  30864169.80  29636228.70
# 28 Sergipe            14519643.00  15737481.70  15806366.56  15529143.60
#
#                          2023/Out     2023/Nov     2023/Dez
# Unidade da Federação
# 41 Paraná            151522479.20 136377606.71 108392132.04
# 32 Espírito Santo     41809848.79  35767904.73  27677906.02
# 21 Maranhão           39865036.47  33146563.03  23303880.58
# 31 Minas Gerais      219842531.75 188894562.58 150535681.66
# 51 Mato Grosso        21572148.20  18757993.99  13608235.28
# 53 Distrito Federal   29776844.99  27785666.95  22830282.42
# 28 Sergipe            14134633.75   9969199.68   7384410.87
#
# [7 rows x 197 columns]

# %%
dados_usaveis.sample(7).T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
# Algoritmo pseudo aleatório (pseudo randomness)

# 53874
# regra: dividir por 10

# 5387
# regra: dividir por 10

# 538
# regra: dividir por 10

# 53
# regra: dividir por 10

# 5

# %%
import numpy as np

np.random.seed(524387)
dados_usaveis.sample(n=7)
# Out:
#                       2007/Ago   2007/Set    2007/Out    2007/Nov    2007/Dez  \
# Unidade da Federação
# 17 Tocantins           4113.76   76633.06   343702.61  1068685.94  3022200.87
# 26 Pernambuco        400640.85 1088340.42  2973553.48  6699828.82 16919031.39
# 31 Minas Gerais      971394.37 2861781.50 10018011.35 21730281.63 43429517.54
# 22 Piauí             220788.25  353468.67  1078182.68  2406035.32  4929772.93
# 25 Paraíba            97352.78  368130.43  1002088.64  2149873.40  5448177.36
# 29 Bahia             135146.36  448349.75  1382038.11  3348779.62 11948984.56
# 42 Santa Catarina    693955.05 1092964.12  3562300.82  7578502.38 14772555.10
#
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 17 Tocantins           5136474.61  5051932.07  5200151.87  5343714.73
# 26 Pernambuco         51279301.86 26222079.10 30716361.81 30589332.79
# 31 Minas Gerais      206936986.60 70301089.50 79119005.51 79046322.41
# 22 Piauí              11375419.37  9711680.20 10428191.09 10227943.00
# 25 Paraíba            16599004.84 10871589.62 12348758.14 12680965.13
# 29 Bahia              76783410.11 33410124.06 41390189.36 42826993.62
# 42 Santa Catarina     53034384.67 24409572.92 27483480.50 27806641.44
#
#                         2008/Mai  ...     2023/Mar     2023/Abr     2023/Mai  \
# Unidade da Federação              ...
# 17 Tocantins          5344487.99  ...   9423976.82   8387001.61   9839564.73
# 26 Pernambuco        31424612.72  ...  82729361.45  76834730.80  85477212.26
# 31 Minas Gerais      79268070.12  ... 216708207.72 199365192.93 222826001.02
# 22 Piauí             10562148.66  ...  22635444.51  21056425.95  24290899.80
# 25 Paraíba           13258411.71  ...  26455201.21  25608560.61  27755853.91
# 29 Bahia             42159447.09  ... 100041097.28  89986678.49 102912686.46
# 42 Santa Catarina    28354279.52  ...  87375896.09  85008218.70  92358687.52
#
# 12 Acre               3233614.21  1394717.40  587777124.12
# 13 Amazonas          14725982.12 11345788.28 2608718161.49
# 14 Roraima             165184.76    91360.44  451127785.41
# 15 Pará              49646581.93 32989201.74 6309059011.86
#
# [5 rows x 198 columns]

# %% [markdown]
# ## Aula 3.2

# %%
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
#                         2008/Mai  ...    2023/Abr    2023/Mai    2023/Jun  \
# Unidade da Federação              ...
# 11 Rondônia           2280382.58  ... 12460222.12 12505974.83 12009682.89
# 12 Acre               2226577.93  ...  4400113.11  4861672.52  5282731.30
# 13 Amazonas           9079902.15  ... 21147835.83 22951007.22 22636889.89
# 14 Roraima            1027288.73  ...  4659152.88  4915988.80  4097022.28
# 15 Pará              23861080.80  ... 48219884.00 52730367.64 49576192.93
#
#                         2023/Jul    2023/Ago    2023/Set    2023/Out  \
# Unidade da Federação
# 11 Rondônia          11892438.13 12737928.88 12068445.93 10814659.45
# 12 Acre               4830246.24  4925043.24  4329288.81  4071963.23
# 13 Amazonas          22193955.78 21762872.97 16686364.04 17051515.93
# 14 Roraima            3814616.24  3180791.10  2362582.36  1585002.57
# 15 Pará              49819035.62 52500501.45 51714821.84 51237171.71
#
#                         2023/Nov    2023/Dez         Total
# Unidade da Federação
# 11 Rondônia           7839878.93  4969181.30 1391827424.30
# 12 Acre               3233614.21  1394717.40  587777124.12
# 13 Amazonas          14725982.12 11345788.28 2608718161.49
# 14 Roraima             165184.76    91360.44  451127785.41
# 15 Pará              49646581.93 32989201.74 6309059011.86
#
# [5 rows x 198 columns]

# %%
dados_usaveis.sort_values(by="Total")
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 16 Amapá                 33672.74  104822.98   118378.28   226661.18
# 14 Roraima                4785.91   11858.63    43852.67   369328.51
# 12 Acre                  10470.07   14001.71    86200.85   301323.68
# 17 Tocantins              4113.76   76633.06   343702.61  1068685.94
# 11 Rondônia               4209.37   16397.03   133645.19   346912.84
# 28 Sergipe               27453.63   78565.19   122952.94   775705.52
# 13 Amazonas              35752.72   45570.64   416012.30  2020381.79
# 27 Alagoas              104243.75  174024.90   595544.54  1125396.73
# 51 Mato Grosso          2980734892.42
# 22 Piauí                3046635412.58
# 50 Mato Grosso do Sul   3215992389.76
# 25 Paraíba              3507146059.30
# 53 Distrito Federal     3527553849.15
# 24 Rio Grande do Norte  3629760436.32
# 32 Espírito Santo       4768785418.29
# 21 Maranhão             5234954522.75
# 15 Pará                 6309059011.86
# 52 Goiás                6664523717.32
# 23 Ceará                8833520782.89
# 42 Santa Catarina      10742748656.66
# 26 Pernambuco          11510246224.24
# 29 Bahia               13070669826.41
# 33 Rio de Janeiro      14277033723.47
# 43 Rio Grande do Sul   16714933327.60
# 41 Paraná              19700887225.42
# 31 Minas Gerais        27501084385.19
# 35 São Paulo           54243940478.25
#
# [27 rows x 198 columns]

# %%
ordenados_por_total = dados_usaveis.sort_values(by="Total", ascending = False)
ordenados_por_total= ordenados_por_total.drop("Total", axis = 1)
## caso queira carregar apenas na tabela em questão: ordenados_por_total.drop("Total", axis = 1, inplace = True)
ordenados_por_total.head(5)
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1098866284.75 173518271.93 170871122.49
# 31 Minas Gerais      43429517.54  206936986.60  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  253437962.44  44128159.73  42933765.97
#
#                          2008/Abr     2008/Mai  ...     2023/Mar     2023/Abr  \
# Unidade da Federação                            ...
# 35 São Paulo         170591864.96 172732776.61  ... 380675682.67 354544684.13
# 31 Minas Gerais       79046322.41  79268070.12  ... 216708207.72 199365192.93
# 41 Paraná             56115135.82  55574831.93  ... 154908096.89 140829790.10
# 43 Rio Grande do Sul  51972416.77  51679350.79  ... 119704904.74 107919440.17
# 33 Rio de Janeiro     45324789.60  43951349.46  ... 120765143.15 113754321.95
#
#                          2023/Mai     2023/Jun     2023/Jul     2023/Ago  \
# Unidade da Federação
# 35 São Paulo         386515192.31 369420874.89 378210221.65 397095635.88
# 31 Minas Gerais      222826001.02 209415536.12 215203958.92 223107676.13
# 41 Paraná            155962309.38 150601146.87 148652511.49 158580037.53
# 43 Rio Grande do Sul 119911799.35 114180633.26 114821469.38 120841672.92
# 33 Rio de Janeiro    124710154.00 120430350.51 124936573.24 126142216.75
#
#                          2023/Set     2023/Out     2023/Nov     2023/Dez
# Unidade da Federação
# 35 São Paulo         362854888.92 374629976.37 335486802.01 289203731.18
# 31 Minas Gerais      214385538.67 219842531.75 188894562.58 150535681.66
# 41 Paraná            152226546.07 151522479.20 136377606.71 108392132.04
# 43 Rio Grande do Sul 114019622.04 116187553.64 101723680.10  79016335.07
# 33 Rio de Janeiro    122532382.59 127245165.17 110293990.40  85884256.01
#
# [5 rows x 197 columns]

# %%
ordenados_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
colunas_interessadas = ordenados_por_total.columns[6:]
ordenados_por_total = ordenados_por_total[colunas_interessadas]

# %%
ordenados_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %% [markdown]
# ## Aula 4.1

# %%
ordenados_por_total = ordenados_por_total/1_000_000

# %%
axis = ordenados_por_total.head(5).T.plot(figsize=(10,6))
##axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))
axis.set_ylabel("Gasto aprovado em milhões de reais")
axis.set_xlabel("Mês")
# Out:
# Text(0.5, 0, 'Mês')

# %%
meses_filtrados = ordenados_por_total.columns[47:]
ordenados_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %% [markdown]
# #### A célula abaixo mostra como definir uma função:

# %%
## Definindo uma função:

def plota_gastos_por_mes(dados, figsize=(10,6)): 
    axis = dados.T.plot(figsize=figsize)
    axis.set_ylabel("Gasto aprovado em milhões de reais")
    axis.set_xlabel("Mês")

# %%
plota_gastos_por_mes(ordenados_por_total[meses_filtrados].head(3))
plt.ylim(0,600)
# Out:
# (0.0, 600.0)

# %%
plota_gastos_por_mes(ordenados_por_total[ordenados_por_total.columns[45:70]].head(3))
plt.ylim(0,320)
# Out:
# (0.0, 320.0)

# %%
## Gráfico dos últimos meses
plota_gastos_por_mes(ordenados_por_total[ordenados_por_total.columns[-12:]].head(3))
plt.ylim(0,640)
# Out:
# (0.0, 640.0)

# %%
## Gráfico dos últimos 5 anos
plota_gastos_por_mes(ordenados_por_total[ordenados_por_total.columns[-60:]].head(3))
plt.ylim(0,640)
# Out:
# (0.0, 640.0)

# %%
plota_gastos_por_mes(ordenados_por_total.head(3))
plt.ylim(0,640)
# Out:
# (0.0, 640.0)

# %%
plota_gastos_por_mes(ordenados_por_total.head(5))
plt.ylim(0,640)
# Out:
# (0.0, 640.0)

# %%
plota_gastos_por_mes(ordenados_por_total.head(5), figsize=(6,6))
plt.ylim(0,640)
plt.xticks(rotation=75)
# Out:
# (array([-25.,   0.,  25.,  50.,  75., 100., 125., 150., 175., 200.]),
#  [Text(-25.0, 0, '2021/Dez'),
#   Text(0.0, 0, '2008/Fev'),
#   Text(25.0, 0, '2010/Mar'),
#   Text(50.0, 0, '2012/Abr'),
#   Text(75.0, 0, '2014/Mai'),
#   Text(100.0, 0, '2016/Jun'),
#   Text(125.0, 0, '2018/Jul'),
#   Text(150.0, 0, '2020/Ago'),
#   Text(175.0, 0, '2022/Set'),
#   Text(200.0, 0, '')])

# %%
plota_gastos_por_mes(ordenados_por_total.head(5), figsize=(20,6))
plt.ylim(0,640)
# Out:
# (0.0, 640.0)

# %% [markdown]
# ## Aula 5.1

# %%
mes_mais_recente = ordenados_por_total.columns[-1]
mes_mais_recente
# Out:
# '2023/Dez'

# %%
gastos_do_mais_recente = ordenados_por_total[mes_mais_recente]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo           289.20
# 31 Minas Gerais        150.54
# 41 Paraná              108.39
# 43 Rio Grande do Sul    79.02
# 33 Rio de Janeiro       85.88
# Name: 2023/Dez, dtype: float64

# %%
gastos_do_mais_recente.plot()
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
gastos_do_mais_recente.plot(kind='pie')
# Out:
# <Axes: ylabel='2023/Dez'>

# %%
gastos_do_mais_recente.sample(frac=1).plot(kind='pie')
# Out:
# <Axes: ylabel='2023/Dez'>

# %%
gastos_do_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo             289.20
# 31 Minas Gerais          150.54
# 41 Paraná                108.39
# 43 Rio Grande do Sul      79.02
# 33 Rio de Janeiro         85.88
# 29 Bahia                  63.60
# 26 Pernambuco             70.51
# 42 Santa Catarina         59.85
# 23 Ceará                  39.04
# 52 Goiás                  35.60
# 15 Pará                   32.99
# 21 Maranhão               23.30
# 32 Espírito Santo         27.68
# 24 Rio Grande do Norte    20.11
# 53 Distrito Federal       22.83
# 25 Paraíba                22.92
# 50 Mato Grosso do Sul     11.10
# 22 Piauí                  15.25
# 51 Mato Grosso            13.61
# 27 Alagoas                14.22
# 13 Amazonas               11.35
# 28 Sergipe                 7.38
# 11 Rondônia                4.97
# 17 Tocantins               2.58
# 12 Acre                    1.39
# 14 Roraima                 0.09
# 16 Amapá                   2.77
# Name: 2023/Dez, dtype: float64

# %%
gastos_do_mais_recente.loc["41 Paraná"]
# Out:
# 108.39213204

# %%
## Tabela de proporção de gastos entre estados, usando como partida os valores do Paraná
gastos_do_mais_recente / gastos_do_mais_recente.loc["41 Paraná"]
# Out:
# Unidade da Federação
# 35 São Paulo             2.67
# 31 Minas Gerais          1.39
# 41 Paraná                1.00
# 43 Rio Grande do Sul     0.73
# 33 Rio de Janeiro        0.79
# 29 Bahia                 0.59
# 26 Pernambuco            0.65
# 42 Santa Catarina        0.55
# 23 Ceará                 0.36
# 52 Goiás                 0.33
# 15 Pará                  0.30
# 21 Maranhão              0.21
# 32 Espírito Santo        0.26
# 24 Rio Grande do Norte   0.19
# 53 Distrito Federal      0.21
# 25 Paraíba               0.21
# 50 Mato Grosso do Sul    0.10
# 22 Piauí                 0.14
# 51 Mato Grosso           0.13
# 27 Alagoas               0.13
# 13 Amazonas              0.10
# 28 Sergipe               0.07
# 11 Rondônia              0.05
# 17 Tocantins             0.02
# 12 Acre                  0.01
# 14 Roraima               0.00
# 16 Amapá                 0.03
# Name: 2023/Dez, dtype: float64

# %%
tabela_de_comparacao = gastos_do_mais_recente / gastos_do_mais_recente.loc["41 Paraná"]
tabela_de_comparacao.head(5)
# Out:
# Unidade da Federação
# 35 São Paulo           2.67
# 31 Minas Gerais        1.39
# 41 Paraná              1.00
# 43 Rio Grande do Sul   0.73
# 33 Rio de Janeiro      0.79
# Name: 2023/Dez, dtype: float64

# %%
tabela_de_comparacao.plot(kind = "bar")
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
tabela_de_comparacao.plot(kind = "barh")
# Out:
# <Axes: ylabel='Unidade da Federação'>

# %%
tabela_de_comparacao = tabela_de_comparacao.sort_values(ascending=False)
tabela_de_comparacao.plot(kind = "bar")
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %% [markdown]
# # Módulo 2: Visualização de dados

# %% [markdown]
# ### Aula 1.1

# %%
ibge_estimativa = pd.read_excel('C:/Users/flora/OneDrive/Documentos/POS_GRADUCAO/Fase 01 - Data Analysis and Exploration/2 - Visualização de Dados/estimativa_dou_2020.xlsx')
ibge_estimativa.head()
# Out:
#   ESTIMATIVAS DA POPULAÇÃO RESIDENTE NO BRASIL E UNIDADES DA FEDERAÇÃO COM DATA DE REFERÊNCIA EM 1º DE JULHO DE 2020  \
# 0                     BRASIL E UNIDADES DA FEDERAÇÃO
# 1                                             Brasil
# 2                                       Região Norte
# 3                                           Rondônia
# 4                                               Acre
#
#    Unnamed: 1          Unnamed: 2
# 0         NaN  POPULAÇÃO ESTIMADA
# 1         NaN           211755692
# 2         NaN            18672591
# 3         NaN             1796460
# 4         NaN              894470

# %%
dados_da_populacao = """Posição	Unidade federativa	População	% da pop. total	País comparável
(habitantes)

1	 São Paulo	46 649 132	21,9%	Flag of Spain.svg Espanha (46 439 864)
2	 Minas Gerais	21 411 923	10,1%	 Sri Lanka (20 675 000)
3	 Rio de Janeiro	17 463 349	8,2%	 Países Baixos (16 922 900)
4	Bahia Bahia	14 985 284	7,1%	 Chade (14 037 000)
5	 Paraná	11 597 484	5,4%	 Bolívia (11 410 651)
6	 Rio Grande do Sul	11 466 630	5,4%	 Bélgica (11 250 659)
7	 Pernambuco	9 674 793	4,5%	 Bielorrússia (9 485 300)
8	 Ceará	9 240 580	4,3%	 Emirados Árabes Unidos (9 157 000)
9	Pará Pará	8 777 124	4,1%	 Áustria (8 602 112)
10	 Santa Catarina	7 338 473	3,4%	 Sérvia (7 114 393)
11	 Goiás	7 206 589	3,4%	 Paraguai (7 003 406)
12	 Maranhão	7 153 262	3,4%	 Paraguai (7 003 406)
13	 Amazonas	4 269 995	2,0%	 Líbano (4 168 000)
14	 Espírito Santo	4 108 508	1,9%	 Líbano (4 168 000)
15	 Paraíba	4 059 905	1,9%	 Líbano (4 168 000)
16	 Mato Grosso	3 567 234	1,7%	 Uruguai (3 415 866)
17	 Rio Grande do Norte	3 560 903	1,7%	 Uruguai (3 415 866)
18	 Alagoas	3 365 351	1,6%	 Uruguai (3 415 866)
19	 Piauí	3 289 290	1,6%	 Kuwait (3 268 431)
20	 Distrito Federal	3 094 325	1,4%	 Lituânia (2 900 787)
21	 Mato Grosso do Sul	2 839 188	1,3%	 Jamaica (2 717 991)
22	 Sergipe	2 338 474	1,1%	 Namíbia (2 280 700)
23	 Rondônia	1 815 278	0,8%	 Gabão (1 725 000)
24	 Tocantins	1 607 363	0,7%	 Bahrein (1 359 800)
25	 Acre	906 876	0,4%	 Fiji (859 178)
26	 Amapá	877 613	0,4%	 Fiji (859 178)
27	 Roraima	652 713	0,3%	 Luxemburgo (562 958)"""

# fonte https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o#cite_note-IBGE_POP-1
# fonte indireta IBGE

# %%
from io import StringIO
dados_da_populacao_io = StringIO(dados_da_populacao)

populacao = pd.read_csv(dados_da_populacao_io, sep="\t")
populacao = populacao.dropna()
populacao.head()
# Out:
#   Posição Unidade federativa   População % da pop. total  \
# 1       1          São Paulo  46 649 132           21,9%
# 2       2       Minas Gerais  21 411 923           10,1%
# 3       3     Rio de Janeiro  17 463 349            8,2%
# 4       4        Bahia Bahia  14 985 284            7,1%
# 5       5             Paraná  11 597 484            5,4%
#
#                           País comparável
# 1  Flag of Spain.svg Espanha (46 439 864)
# 2                  Sri Lanka (20 675 000)
# 3              Países Baixos (16 922 900)
# 4                      Chade (14 037 000)
# 5                    Bolívia (11 410 651)

# %% [markdown]
# ### Aula 1.2

# %%
populacao.columns = ["posicao", "uf", "populacao", "porcentagem", "pais_comparavel"]
populacao["populacao"] = populacao["populacao"].str.replace(" ", "").astype(int)
populacao = populacao[["uf", "populacao"]]
populacao.head()
# Out:
#                 uf  populacao
# 1        São Paulo   46649132
# 2     Minas Gerais   21411923
# 3   Rio de Janeiro   17463349
# 4      Bahia Bahia   14985284
# 5           Paraná   11597484

# %%
gastos_do_mais_recente.index = gastos_do_mais_recente.index.str[3:]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# São Paulo           289.20
# Minas Gerais        150.54
# Paraná              108.39
# Rio Grande do Sul    79.02
# Rio de Janeiro       85.88
# Name: 2023/Dez, dtype: float64

# %%
populacao = populacao.set_index("uf")
populacao.head()
# Out:
#                  populacao
# uf
#  São Paulo        46649132
#  Minas Gerais     21411923
#  Rio de Janeiro   17463349
# Bahia Bahia       14985284
#  Paraná           11597484

# %%
for estado in gastos_do_mais_recente.index:
  populacao.index = populacao.index.str.replace(f"{estado} {estado}", estado)
populacao.index
# Out:
# Index([' São Paulo', ' Minas Gerais', ' Rio de Janeiro', 'Bahia', ' Paraná',
#        ' Rio Grande do Sul', ' Pernambuco', ' Ceará', 'Pará',
#        ' Santa Catarina', ' Goiás', ' Maranhão', ' Amazonas',
#        ' Espírito Santo', ' Paraíba', ' Mato Grosso', ' Rio Grande do Norte',
#        ' Alagoas', ' Piauí', ' Distrito Federal', ' Mato Grosso do Sul',
#        ' Sergipe', ' Rondônia', ' Tocantins', ' Acre', ' Amapá', ' Roraima'],
#       dtype='object', name='uf')

# %%
gastos_e_populacao = populacao.join(gastos_do_mais_recente)
gastos_e_populacao.head()
# Out:
#                  populacao  2023/Dez
# uf
#  São Paulo        46649132       NaN
#  Minas Gerais     21411923       NaN
#  Rio de Janeiro   17463349       NaN
# Bahia             14985284     63.60
#  Paraná           11597484       NaN

# %%
ultima_coluna = gastos_e_populacao.columns[-1]
gastos_e_populacao["gastos"] = gastos_e_populacao[ultima_coluna] * 1_000_000
gastos_e_populacao.plot()
# Out:
# <Axes: xlabel='uf'>
